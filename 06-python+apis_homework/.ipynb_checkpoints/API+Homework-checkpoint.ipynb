# %% [markdown]
# # ANALYSES

# %% [markdown]
# ###### Trend 1 : As we get closer to the equator, the temperature will increase significantly as implied by the Max Temp v Latitude plot
# ###### Trend 2 : Looking at the Max Wind speeds plot, we can see that at 0 degrees, theres a cluster of cities. This implies that cities closer to 0 degree latitudes have lower wind speeds than not.
# ###### Trend 3 : Humidity percentages increase closer to the equator

# %% [markdown]
# --------------------------------------

# %% [markdown]
# ##### Import Dependencies

# %%
import json
import matplotlib.pyplot as plt
import pandas as pd
import requests as req
from citipy import citipy
import random
import numpy as np
from array import array
import seaborn as sns

# %% [markdown]
# ##### Retrieve Weather API Information

# %%
weather_url = 'https://api.openweathermap.org/data/2.5/weather?'
weather_apiKey = 'e5613f31e67384f3359727ac648d4bca'

# %% [markdown]
# ##### Generating 600 random cities

# %%
lat =  np.random.uniform(-90,90,600)
long = np.random.uniform(-180,180,600)
coordinates_df = pd.DataFrame({'Latitude':lat, 'Longtitude':long})
coordinates_df.head()
# Out:
#     Latitude  Longtitude
# 0  -8.921170 -126.889341
# 1 -77.357296 -146.751413
# 2 -52.958458  131.446244
# 3  18.990164 -127.549987
# 4 -28.651762 -145.698630

# %%
#Here we are iterrating through the rows of the dataframe and using the citipy library to find the nearest city for
##each corresponding lat,lon pair
for index,row in coordinates_df.iterrows():
    lat= row['Latitude']
    lon = row['Longtitude']
    city = citipy.nearest_city(lat, lon).city_name
    coordinates_df.set_value(index,'Nearest City',city)
coordinates_df.dropna(how='any')    
coordinates_df.head()
# Out:
#     Latitude  Longtitude    Nearest City
# 0  -8.921170 -126.889341          atuona
# 1 -77.357296 -146.751413         mataura
# 2 -52.958458  131.446244   mount gambier
# 3  18.990164 -127.549987  guerrero negro
# 4 -28.651762 -145.698630         mataura

# %% [markdown]
# ##### Perform API Calls

# %%
weather_info=[]
units = "metric"

for index,row in coordinates_df.iterrows():
    nc = row['Nearest City']
    queryString = weather_url + "appid=" + weather_apiKey + "&q=" + nc + "&units=" + units
    weather_response = req.get(queryString).json()
    weather_info.append(weather_response)

# weather_response
weather_info
# Out:
# [{'base': 'stations',
#   'clouds': {'all': 92},
#   'cod': 200,
#   'coord': {'lat': -9.8, 'lon': -139.03},
#   'dt': 1521276816,
#   'id': 4020109,
#   'main': {'grnd_level': 1024.2,
#    'humidity': 98,
#    'pressure': 1024.2,
#    'sea_level': 1024.26,
#    'temp': 27.95,
#    'temp_max': 27.95,
#    'temp_min': 27.95},
#   'name': 'Atuona',
#   'sys': {'country': 'PF',
#    'message': 0.0034,
#    'sunrise': 1521300011,
#    'sunset': 1521343687},
#   'weather': [{'description': 'overcast clouds',
#     'icon': '04n',
#     'id': 804,
#     'main': 'Clouds'}],
#   'wind': {'deg': 95.5003, 'speed': 7.17}},
#  {'base': 'stations',
#   'clouds': {'all': 8},
#   'cod': 200,
#   'coord': {'lat': -46.19, 'lon': 168.86},
#   'dt': 1521276817,
#   'id': 6201424,
#   'main': {'grnd_level': 1021.93,
#    'humidity': 79,
#    'pressure': 1021.93,
#    'sea_level': 1037.36,
#    'temp': 7.65,
#    'temp_max': 7.65,
#    'temp_min': 7.65},
#   'name': 'Mataura',
#   'sys': {'country': 'NZ',
#    'message': 0.0042,
#    'sunrise': 1521225741,
#    'sunset': 1521270157},
#   'weather': [{'description': 'clear sky',
#     'icon': '02n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 128, 'speed': 2.12}},
#  {'base': 'stations',
#   'clouds': {'all': 92},
#   'cod': 200,
#   'coord': {'lat': -37.83, 'lon': 140.78},
#   'dt': 1521276780,
#   'id': 2156643,
#   'main': {'grnd_level': 1006.85,
#    'humidity': 27,
#    'pressure': 1006.85,
#    'sea_level': 1015.1,
#    'temp': 28.15,
#    'temp_max': 28.15,
#    'temp_min': 28.15},
#   'name': 'Mount Gambier',
#   'sys': {'country': 'AU',
#    'message': 0.0036,
#    'sunrise': 1521232610,
#    'sunset': 1521276778},
#   'weather': [{'description': 'overcast clouds',
#     'icon': '04d',
#     'id': 804,
#     'main': 'Clouds'}],
#   'wind': {'deg': 322.5, 'speed': 6.12}},
#  {'base': 'stations',
#   'clouds': {'all': 92},
#   'cod': 200,
#   'coord': {'lat': 27.97, 'lon': -114.04},
#   'dt': 1521276818,
#   'id': 4021858,
#   'main': {'grnd_level': 1018.12,
#    'humidity': 85,
#    'pressure': 1018.12,
#    'sea_level': 1029.78,
#    'temp': 13.8,
#    'temp_max': 13.8,
#    'temp_min': 13.8},
#   'name': 'Guerrero Negro',
#   'sys': {'country': 'MX',
#    'message': 0.0037,
#    'sunrise': 1521294173,
#    'sunset': 1521337567},
#   'weather': [{'description': 'overcast clouds',
#     'icon': '04n',
#     'id': 804,
#     'main': 'Clouds'}],
#   'wind': {'deg': 311, 'speed': 5.27}},
#  {'base': 'stations',
#   'clouds': {'all': 8},
#   'cod': 200,
#   'coord': {'lat': -46.19, 'lon': 168.86},
#   'dt': 1521276817,
#   'id': 6201424,
#   'main': {'grnd_level': 1021.93,
#    'humidity': 79,
#    'pressure': 1021.93,
#    'sea_level': 1037.36,
#    'temp': 7.65,
#    'temp_max': 7.65,
#    'temp_min': 7.65},
#   'name': 'Mataura',
#   'sys': {'country': 'NZ',
#    'message': 0.0042,
#    'sunrise': 1521225741,
#    'sunset': 1521270157},
#   'weather': [{'description': 'clear sky',
#     'icon': '02n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 128, 'speed': 2.12}},
#  {'cod': '404', 'message': 'city not found'},
#  {'base': 'stations',
#   'clouds': {'all': 24},
#   'cod': 200,
#   'coord': {'lat': 13.13, 'lon': 123.76},
#   'dt': 1521276820,
#   'id': 1706889,
#   'main': {'grnd_level': 1011.15,
#    'humidity': 76,
#    'pressure': 1011.15,
#    'sea_level': 1024.63,
#    'temp': 27.65,
#    'temp_max': 27.65,
#    'temp_min': 27.65},
#   'name': 'Puro',
#   'sys': {'country': 'PH',
#    'message': 0.0047,
#    'sunrise': 1521237071,
#    'sunset': 1521280534},
#   'weather': [{'description': 'few clouds',
#     'icon': '02d',
#     'id': 801,
#     'main': 'Clouds'}],
#   'wind': {'deg': 42.5003, 'speed': 4.77}},
#  {'cod': '404', 'message': 'city not found'},
#  {'base': 'stations',
#   'clouds': {'all': 88},
#   'cod': 200,
#   'coord': {'lat': -7.71, 'lon': -67},
#   'dt': 1521276821,
#   'id': 3662927,
#   'main': {'grnd_level': 1011.96,
#    'humidity': 94,
#    'pressure': 1011.96,
#    'sea_level': 1023.21,
#    'temp': 23.45,
#    'temp_max': 23.45,
#    'temp_min': 23.45},
#   'name': 'Pauini',
#   'sys': {'country': 'BR',
#    'message': 0.0051,
#    'sunrise': 1521282736,
#    'sunset': 1521326398},
#   'weather': [{'description': 'overcast clouds',
#     'icon': '04n',
#     'id': 804,
#     'main': 'Clouds'}],
#   'wind': {'deg': 97.5003, 'speed': 1.07}},
#  {'cod': '404', 'message': 'city not found'},
#  {'cod': '404', 'message': 'city not found'},
#  {'base': 'stations',
#   'clouds': {'all': 100},
#   'cod': 200,
#   'coord': {'lat': -5.81, 'lon': -61.3},
#   'dt': 1521276823,
#   'id': 3663503,
#   'main': {'grnd_level': 1014.96,
#    'humidity': 96,
#    'pressure': 1014.96,
#    'sea_level': 1023.7,
#    'temp': 23.15,
#    'temp_max': 23.15,
#    'temp_min': 23.15},
#   'name': 'Manicore',
#   'sys': {'country': 'BR',
#    'message': 0.0036,
#    'sunrise': 1521281378,
#    'sunset': 1521325022},
#   'weather': [{'description': 'overcast clouds',
#     'icon': '04n',
#     'id': 804,
#     'main': 'Clouds'}],
#   'wind': {'deg': 82.0003, 'speed': 0.87}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -19.99, 'lon': 23.42},
#   'dt': 1521273600,
#   'id': 933366,
#   'main': {'humidity': 65,
#    'pressure': 1016,
#    'temp': 27,
#    'temp_max': 27,
#    'temp_min': 27},
#   'name': 'Maun',
#   'sys': {'country': 'BW',
#    'id': 6639,
#    'message': 0.0034,
#    'sunrise': 1521260957,
#    'sunset': 1521304772,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#     'icon': '01d',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 230, 'speed': 1.5}},
#  {'base': 'stations',
#   'clouds': {'all': 64},
#   'cod': 200,
#   'coord': {'lat': -23.12, 'lon': -134.97},
#   'dt': 1521276824,
#   'id': 4030556,
#   'main': {'grnd_level': 1032.23,
#    'humidity': 96,
#    'pressure': 1032.23,
#    'sea_level': 1032.29,
#    'temp': 27.6,
#    'temp_max': 27.6,
#    'temp_min': 27.6},
#   'name': 'Rikitea',
#   'sys': {'country': 'PF',
#    'message': 0.0037,
#    'sunrise': 1521298958,
#    'sunset': 1521342780},
#   'weather': [{'description': 'broken clouds',
#     'icon': '04n',
#     'id': 803,
#     'main': 'Clouds'}],
#   'wind': {'deg': 90.0003, 'speed': 6.77}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': 45.36, 'lon': -73.48},
#   'dt': 1521274500,
#   'id': 6138908,
#   'main': {'humidity': 41,
#    'pressure': 1005,
#    'temp': -8.78,
#    'temp_max': -7,
#    'temp_min': -11},
#   'name': 'Saint-Philippe',
#   'sys': {'country': 'CA',
#    'id': 3851,
#    'message': 0.0103,
#    'sunrise': 1521284518,
#    'sunset': 1521327780,
#    'type': 1},
#   'visibility': 14484,
#   'weather': [{'description': 'broken clouds',
#     'icon': '04n',
#     'id': 803,
#     'main': 'Clouds'}],
#   'wind': {'deg': 280, 'speed': 4.6}},
#  {'base': 'stations',
#   'clouds': {'all': 20},
#   'cod': 200,
#   'coord': {'lat': -0.6, 'lon': 73.08},
#   'dt': 1521276825,
#   'id': 1282256,
#   'main': {'grnd_level': 1021.2,
#    'humidity': 100,
#    'pressure': 1021.2,
#    'sea_level': 1021.22,
#    'temp': 29.3,
#    'temp_max': 29.3,
#    'temp_min': 29.3},
#   'name': 'Hithadhoo',
#   'sys': {'country': 'MV',
#    'message': 0.005,
#    'sunrise': 1521249159,
#    'sunset': 1521292756},
#   'weather': [{'description': 'few clouds',
#     'icon': '02d',
#     'id': 801,
#     'main': 'Clouds'}],
#   'wind': {'deg': 353.5, 'speed': 6.62}},
#  {'base': 'stations',
#   'clouds': {'all': 20},
#   'cod': 200,
#   'coord': {'lat': 19.71, 'lon': -155.08},
#   'dt': 1521273360,
#   'id': 5855927,
#   'main': {'humidity': 88,
#    'pressure': 1017,
#    'temp': 17.38,
#    'temp_max': 23,
#    'temp_min': 13},
#   'name': 'Hilo',
#   'sys': {'country': 'US',
#    'id': 818,
#    'message': 0.0044,
#    'sunrise': 1521303986,
#    'sunset': 1521347441,
#    'type': 1},
#   'visibility': 16093,
#   'weather': [{'description': 'few clouds',
#     'icon': '02n',
#     'id': 801,
#     'main': 'Clouds'}],
#   'wind': {'deg': 210, 'speed': 2.1}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -46.43, 'lon': -67.52},
#   'dt': 1521276826,
#   'id': 3863379,
#   'main': {'grnd_level': 996.07,
#    'humidity': 92,
#    'pressure': 996.07,
#    'sea_level': 1017.5,
#    'temp': 7.75,
#    'temp_max': 7.75,
#    'temp_min': 7.75},
#   'name': 'Mar del Plata',
#   'sys': {'country': 'AR',
#    'message': 0.0071,
#    'sunrise': 1521282523,
#    'sunset': 1521326815},
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 261, 'speed': 3.62}},
#  {'base': 'stations',
#   'clouds': {'all': 64},
#   'cod': 200,
#   'coord': {'lat': -23.12, 'lon': -134.97},
#   'dt': 1521276824,
#   'id': 4030556,
#   'main': {'grnd_level': 1032.23,
#    'humidity': 96,
#    'pressure': 1032.23,
#    'sea_level': 1032.29,
#    'temp': 27.6,
#    'temp_max': 27.6,
#    'temp_min': 27.6},
#   'name': 'Rikitea',
#   'sys': {'country': 'PF',
#    'message': 0.0037,
#    'sunrise': 1521298958,
#    'sunset': 1521342780},
#   'weather': [{'description': 'broken clouds',
#     'icon': '04n',
#     'id': 803,
#     'main': 'Clouds'}],
#   'wind': {'deg': 90.0003, 'speed': 6.77}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -46.43, 'lon': -67.52},
#   'dt': 1521276826,
#   'id': 3863379,
#   'main': {'grnd_level': 996.07,
#    'humidity': 92,
#    'pressure': 996.07,
#    'sea_level': 1017.5,
#    'temp': 7.75,
#    'temp_max': 7.75,
#    'temp_min': 7.75},
#   'name': 'Mar del Plata',
#   'sys': {'country': 'AR',
#    'message': 0.0071,
#    'sunrise': 1521282523,
#    'sunset': 1521326815},
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 261, 'speed': 3.62}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 77.48, 'lon': -69.36},
#   'dt': 1521276828,
#   'id': 3831208,
#   'main': {'grnd_level': 1004.5,
#    'humidity': 65,
#    'pressure': 1004.5,
#    'sea_level': 1040.35,
#    'temp': -30.35,
#    'temp_max': -30.35,
#    'temp_min': -30.35},
#   'name': 'Qaanaaq',
#   'sys': {'country': 'GL',
#    'message': 0.0038,
#    'sunrise': 1521283838,
#    'sunset': 1521326646},
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 94.5003, 'speed': 3.37}},
#  {'base': 'stations',
#   'clouds': {'all': 1},
#   'cod': 200,
#   'coord': {'lat': 39.12, 'lon': -121.64},
#   'dt': 1521275700,
#   'id': 5397851,
#   'main': {'humidity': 86,
#    'pressure': 1014,
#    'temp': 5.23,
#    'temp_max': 7,
#    'temp_min': 4},
#   'name': 'South Yuba City',
#   'sys': {'country': 'US',
#    'id': 408,
#    'message': 0.0038,
#    'sunrise': 1521296037,
#    'sunset': 1521339363,
#    'type': 1},
#   'visibility': 16093,
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 150, 'speed': 4.1}},
#  {'base': 'stations',
#   'clouds': {'all': 48},
#   'cod': 200,
#   'coord': {'lat': -33.59, 'lon': 26.89},
#   'dt': 1521276829,
#   'id': 964432,
#   'main': {'grnd_level': 1029.07,
#    'humidity': 87,
#    'pressure': 1029.07,
#    'sea_level': 1037.96,
#    'temp': 20.65,
#    'temp_max': 20.65,
#    'temp_min': 20.65},
#   'name': 'Port Alfred',
#   'sys': {'country': 'ZA',
#    'message': 0.0038,
#    'sunrise': 1521260008,
#    'sunset': 1521304041},
#   'weather': [{'description': 'scattered clouds',
#     'icon': '03d',
#     'id': 802,
#     'main': 'Clouds'}],
#   'wind': {'deg': 79.5003, 'speed': 6.42}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 69.7, 'lon': 170.27},
#   'dt': 1521276830,
#   'id': 2122090,
#   'main': {'grnd_level': 1032.23,
#    'humidity': 55,
#    'pressure': 1032.23,
#    'sea_level': 1040.92,
#    'temp': -35.5,
#    'temp_max': -35.5,
#    'temp_min': -35.5},
#   'name': 'Pevek',
#   'sys': {'country': 'RU',
#    'message': 0.0049,
#    'sunrise': 1521226367,
#    'sunset': 1521269032},
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 39.5003, 'speed': 0.87}},
#  {'base': 'stations',
#   'clouds': {'all': 90},
#   'cod': 200,
#   'coord': {'lat': 70.86, 'lon': 29.09},
#   'dt': 1521273000,
#   'id': 780687,
#   'main': {'humidity': 100,
#    'pressure': 1013,
#    'temp': 1,
#    'temp_max': 1,
#    'temp_min': 1},
#   'name': 'Berlevag',
#   'sys': {'country': 'NO',
#    'id': 5282,
#    'message': 0.0042,
#    'sunrise': 1521260163,
#    'sunset': 1521302999,
#    'type': 1},
#   'visibility': 2000,
#   'weather': [{'description': 'light shower snow',
#     'icon': '13d',
#     'id': 620,
#     'main': 'Snow'}],
#   'wind': {'deg': 260, 'speed': 4.1}},
#  {'base': 'stations',
#   'clouds': {'all': 80},
#   'cod': 200,
#   'coord': {'lat': 15.34, 'lon': 74.49},
#   'dt': 1521276831,
#   'id': 1273574,
#   'main': {'grnd_level': 957.08,
#    'humidity': 77,
#    'pressure': 957.08,
#    'sea_level': 1021.35,
#    'temp': 28.3,
#    'temp_max': 28.3,
#    'temp_min': 28.3},
#   'name': 'Vaini',
#   'rain': {'3h': 2.314},
#   'sys': {'country': 'IN',
#    'message': 0.0043,
#    'sunrise': 1521248901,
#    'sunset': 1521292350},
#   'weather': [{'description': 'light rain',
#     'icon': '10d',
#     'id': 500,
#     'main': 'Rain'}],
#   'wind': {'deg': 138.5, 'speed': 1.67}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': -23.99, 'lon': -46.26},
#   'dt': 1521273600,
#   'id': 3461789,
#   'main': {'humidity': 88,
#    'pressure': 1017,
#    'temp': 21,
#    'temp_max': 21,
#    'temp_min': 21},
#   'name': 'Guaruja',
#   'sys': {'country': 'BR',
#    'id': 4575,
#    'message': 0.0038,
#    'sunrise': 1521277655,
#    'sunset': 1521321510,
#    'type': 1},
#   'visibility': 9000,
#   'weather': [{'description': 'broken clouds',
#     'icon': '04n',
#     'id': 803,
#     'main': 'Clouds'}],
#   'wind': {'deg': 140, 'speed': 2.1}},
#  {'base': 'stations',
#   'clouds': {'all': 24},
#   'cod': 200,
#   'coord': {'lat': -34.42, 'lon': 19.24},
#   'dt': 1521276832,
#   'id': 3366880,
#   'main': {'grnd_level': 992.34,
#    'humidity': 53,
#    'pressure': 992.34,
#    'sea_level': 1031.8,
#    'temp': 20.75,
#    'temp_max': 20.75,
#    'temp_min': 20.75},
#   'name': 'Hermanus',
#   'sys': {'country': 'ZA',
#    'message': 0.0032,
#    'sunrise': 1521261836,
#    'sunset': 1521305883},
#   'weather': [{'description': 'few clouds',
#     'icon': '02d',
#     'id': 801,
#     'main': 'Clouds'}],
#   'wind': {'deg': 79.5003, 'speed': 3.67}},
#  {'base': 'stations',
#   'clouds': {'all': 12},
#   'cod': 200,
#   'coord': {'lat': 6.12, 'lon': 81.12},
#   'dt': 1521276833,
#   'id': 1244926,
#   'main': {'grnd_level': 1018.77,
#    'humidity': 96,
#    'pressure': 1018.77,
#    'sea_level': 1021.47,
#    'temp': 29.2,
#    'temp_max': 29.2,
#    'temp_min': 29.2},
#   'name': 'Hambantota',
#   'sys': {'country': 'LK',
#    'message': 0.0033,
#    'sunrise': 1521247265,
#    'sunset': 1521290797},
#   'weather': [{'description': 'few clouds',
#     'icon': '02d',
#     'id': 801,
#     'main': 'Clouds'}],
#   'wind': {'deg': 82.0003, 'speed': 6.07}},
#  {'cod': '404', 'message': 'city not found'},
#  {'base': 'stations',
#   'clouds': {'all': 40},
#   'cod': 200,
#   'coord': {'lat': 1.44, 'lon': 125.19},
#   'dt': 1521275400,
#   'id': 1648636,
#   'main': {'humidity': 66,
#    'pressure': 1009,
#    'temp': 30,
#    'temp_max': 30,
#    'temp_min': 30},
#   'name': 'Bitung',
#   'sys': {'country': 'ID',
#    'id': 8012,
#    'message': 0.0047,
#    'sunrise': 1521236666,
#    'sunset': 1521280242,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'scattered clouds',
#     'icon': '03d',
#     'id': 802,
#     'main': 'Clouds'}],
#   'wind': {'deg': 250, 'speed': 4.1}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -33.64, 'lon': 115.35},
#   'dt': 1521276834,
#   'id': 2075265,
#   'main': {'grnd_level': 1032.23,
#    'humidity': 100,
#    'pressure': 1032.23,
#    'sea_level': 1033.3,
#    'temp': 19.35,
#    'temp_max': 19.35,
#    'temp_min': 19.35},
#   'name': 'Busselton',
#   'sys': {'country': 'AU',
#    'message': 0.0034,
#    'sunrise': 1521238766,
#    'sunset': 1521282831},
#   'weather': [{'description': 'clear sky',
#     'icon': '01d',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 187.5, 'speed': 8.72}},
#  {'cod': '404', 'message': 'city not found'},
#  {'base': 'stations',
#   'clouds': {'all': 88},
#   'cod': 200,
#   'coord': {'lat': -1.57, 'lon': 9.26},
#   'dt': 1521276835,
#   'id': 2396853,
#   'main': {'grnd_level': 1024.77,
#    'humidity': 100,
#    'pressure': 1024.77,
#    'sea_level': 1024.71,
#    'temp': 27.55,
#    'temp_max': 27.55,
#    'temp_min': 27.55},
#   'name': 'Omboue',
#   'sys': {'country': 'GA',
#    'message': 0.0035,
#    'sunrise': 1521264467,
#    'sunset': 1521308073},
#   'weather': [{'description': 'overcast clouds',
#     'icon': '04d',
#     'id': 804,
#     'main': 'Clouds'}],
#   'wind': {'deg': 229.5, 'speed': 3.77}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': 55.74, 'lon': -97.86},
#   'dt': 1521273600,
#   'id': 6165406,
#   'main': {'humidity': 61,
#    'pressure': 1011,
#    'temp': -10,
#    'temp_max': -10,
#    'temp_min': -10},
#   'name': 'Thompson',
#   'sys': {'country': 'CA',
#    'id': 3406,
#    'message': 0.0027,
#    'sunrise': 1521290411,
#    'sunset': 1521333608,
#    'type': 1},
#   'visibility': 24140,
#   'weather': [{'description': 'broken clouds',
#     'icon': '04n',
#     'id': 803,
#     'main': 'Clouds'}],
#   'wind': {'deg': 70, 'speed': 1.5}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -33.64, 'lon': 115.35},
#   'dt': 1521276834,
#   'id': 2075265,
#   'main': {'grnd_level': 1032.23,
#    'humidity': 100,
#    'pressure': 1032.23,
#    'sea_level': 1033.3,
#    'temp': 19.35,
#    'temp_max': 19.35,
#    'temp_min': 19.35},
#   'name': 'Busselton',
#   'sys': {'country': 'AU',
#    'message': 0.0034,
#    'sunrise': 1521238766,
#    'sunset': 1521282831},
#   'weather': [{'description': 'clear sky',
#     'icon': '01d',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 187.5, 'speed': 8.72}},
#  {'base': 'stations',
#   'clouds': {'all': 64},
#   'cod': 200,
#   'coord': {'lat': -18.17, 'lon': -47.95},
#   'dt': 1521276837,
#   'id': 3466696,
#   'main': {'grnd_level': 939.74,
#    'humidity': 94,
#    'pressure': 939.74,
#    'sea_level': 1024.91,
#    'temp': 19.85,
#    'temp_max': 19.85,
#    'temp_min': 19.85},
#   'name': 'Catalao',
#   'rain': {'3h': 0.475},
#   'sys': {'country': 'BR',
#    'message': 0.0041,
#    'sunrise': 1521278102,
#    'sunset': 1521321880},
#   'weather': [{'description': 'light rain',
#     'icon': '10n',
#     'id': 500,
#     'main': 'Rain'}],
#   'wind': {'deg': 18.0003, 'speed': 2.62}},
#  {'base': 'stations',
#   'clouds': {'all': 92},
#   'cod': 200,
#   'coord': {'lat': -9.8, 'lon': -139.03},
#   'dt': 1521276816,
#   'id': 4020109,
#   'main': {'grnd_level': 1024.2,
#    'humidity': 98,
#    'pressure': 1024.2,
#    'sea_level': 1024.26,
#    'temp': 27.95,
#    'temp_max': 27.95,
#    'temp_min': 27.95},
#   'name': 'Atuona',
#   'sys': {'country': 'PF',
#    'message': 0.0034,
#    'sunrise': 1521300011,
#    'sunset': 1521343687},
#   'weather': [{'description': 'overcast clouds',
#     'icon': '04n',
#     'id': 804,
#     'main': 'Clouds'}],
#   'wind': {'deg': 95.5003, 'speed': 7.17}},
#  {'base': 'stations',
#   'clouds': {'all': 8},
#   'cod': 200,
#   'coord': {'lat': -41.29, 'lon': 174.78},
#   'dt': 1521273600,
#   'id': 2179537,
#   'main': {'humidity': 58,
#    'pressure': 1027,
#    'temp': 14,
#    'temp_max': 14,
#    'temp_min': 14},
#   'name': 'Wellington',
#   'sys': {'country': 'NZ',
#    'id': 8295,
#    'message': 0.0041,
#    'sunrise': 1521224397,
#    'sunset': 1521268668,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#     'icon': '02n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 130, 'speed': 1.5}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': -54.81, 'lon': -68.31},
#   'dt': 1521273600,
#   'id': 3833367,
#   'main': {'humidity': 100,
#    'pressure': 990,
#    'temp': 2,
#    'temp_max': 2,
#    'temp_min': 2},
#   'name': 'Ushuaia',
#   'sys': {'country': 'AR',
#    'id': 4754,
#    'message': 0.0038,
#    'sunrise': 1521282555,
#    'sunset': 1521327143,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#     'icon': '04n',
#     'id': 803,
#     'main': 'Clouds'}],
#   'wind': {'deg': 90, 'speed': 2.6}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': 51.75, 'lon': 12.51},
#   'dt': 1521275520,
#   'id': 2850973,
#   'main': {'humidity': 79,
#    'pressure': 1012,
#    'temp': -6,
#    'temp_max': -6,
#    'temp_min': -6},
#   'name': 'Radis',
#   'sys': {'country': 'DE',
#    'id': 4989,
#    'message': 0.004,
#    'sunrise': 1521263944,
#    'sunset': 1521307099,
#    'type': 1},
#   'visibility': 8000,
#   'weather': [{'description': 'light snow',
#     'icon': '13d',
#     'id': 600,
#     'main': 'Snow'},
#    {'description': 'mist', 'icon': '50d', 'id': 701, 'main': 'Mist'}],
#   'wind': {'deg': 60, 'gust': 11.3, 'speed': 6.2}},
#  {'base': 'stations',
#   'clouds': {'all': 24},
#   'cod': 200,
#   'coord': {'lat': -34.42, 'lon': 19.24},
#   'dt': 1521276832,
#   'id': 3366880,
#   'main': {'grnd_level': 992.34,
#    'humidity': 53,
#    'pressure': 992.34,
#    'sea_level': 1031.8,
#    'temp': 20.75,
#    'temp_max': 20.75,
#    'temp_min': 20.75},
#   'name': 'Hermanus',
#   'sys': {'country': 'ZA',
#    'message': 0.0032,
#    'sunrise': 1521261836,
#    'sunset': 1521305883},
#   'weather': [{'description': 'few clouds',
#     'icon': '02d',
#     'id': 801,
#     'main': 'Clouds'}],
#   'wind': {'deg': 79.5003, 'speed': 3.67}},
#  {'base': 'stations',
#   'clouds': {'all': 20},
#   'cod': 200,
#   'coord': {'lat': 19.71, 'lon': -155.08},
#   'dt': 1521273360,
#   'id': 5855927,
#   'main': {'humidity': 88,
#    'pressure': 1017,
#    'temp': 17.38,
#    'temp_max': 23,
#    'temp_min': 13},
#   'name': 'Hilo',
#   'sys': {'country': 'US',
#    'id': 818,
#    'message': 0.0044,
#    'sunrise': 1521303986,
#    'sunset': 1521347441,
#    'type': 1},
#   'visibility': 16093,
#   'weather': [{'description': 'few clouds',
#     'icon': '02n',
#     'id': 801,
#     'main': 'Clouds'}],
#   'wind': {'deg': 210, 'speed': 2.1}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -33.93, 'lon': 18.42},
#   'dt': 1521276120,
#   'id': 3369157,
#   'main': {'humidity': 38,
#    'pressure': 1018,
#    'temp': 24,
#    'temp_max': 24,
#    'temp_min': 24},
#   'name': 'Cape Town',
#   'sys': {'country': 'ZA',
#    'id': 6529,
#    'message': 0.0047,
#    'sunrise': 1521262038,
#    'sunset': 1521306075,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#     'icon': '01d',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 220, 'speed': 2.6}},
#  {'base': 'stations',
#   'clouds': {'all': 5},
#   'cod': 200,
#   'coord': {'lat': 49.72, 'lon': -86.95},
#   'dt': 1521273600,
#   'id': 5960603,
#   'main': {'humidity': 60,
#    'pressure': 1015,
#    'temp': -14,
#    'temp_max': -14,
#    'temp_min': -14},
#   'name': 'Geraldton',
#   'sys': {'country': 'CA',
#    'id': 3656,
#    'message': 0.0037,
#    'sunrise': 1521287766,
#    'sunset': 1521331003,
#    'type': 1},
#   'visibility': 24140,
#   'weather': [{'description': 'clear sky',
#     'icon': '02n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 50, 'speed': 1.5}},
#  {'cod': '404', 'message': 'city not found'},
#  {'cod': '404', 'message': 'city not found'},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': 37.14, 'lon': -8.45},
#   'dt': 1521275400,
#   'id': 2267254,
#   'main': {'humidity': 77,
#    'pressure': 1009,
#    'temp': 15,
#    'temp_max': 15,
#    'temp_min': 15},
#   'name': 'Lagoa',
#   'sys': {'country': 'PT',
#    'id': 5948,
#    'message': 0.0041,
#    'sunrise': 1521268892,
#    'sunset': 1521312186,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#     'icon': '04d',
#     'id': 803,
#     'main': 'Clouds'}],
#   'wind': {'deg': 240, 'speed': 10.8}},
#  {'base': 'stations',
#   'clouds': {'all': 24},
#   'cod': 200,
#   'coord': {'lat': -23.58, 'lon': 149.07},
#   'dt': 1521276845,
#   'id': 2175403,
#   'main': {'grnd_level': 1003.69,
#    'humidity': 40,
#    'pressure': 1003.69,
#    'sea_level': 1026.33,
#    'temp': 30,
#    'temp_max': 30,
#    'temp_min': 30},
#   'name': 'Bluff',
#   'sys': {'country': 'AU',
#    'message': 0.0039,
#    'sunrise': 1521230766,
#    'sunset': 1521274660},
#   'weather': [{'description': 'few clouds',
#     'icon': '02n',
#     'id': 801,
#     'main': 'Clouds'}],
#   'wind': {'deg': 78.0003, 'speed': 3.57}},
#  {'base': 'stations',
#   'clouds': {'all': 24},
#   'cod': 200,
#   'coord': {'lat': -34.42, 'lon': 19.24},
#   'dt': 1521276832,
#   'id': 3366880,
#   'main': {'grnd_level': 992.34,
#    'humidity': 53,
#    'pressure': 992.34,
#    'sea_level': 1031.8,
#    'temp': 20.75,
#    'temp_max': 20.75,
#    'temp_min': 20.75},
#   'name': 'Hermanus',
#   'sys': {'country': 'ZA',
#    'message': 0.0032,
#    'sunrise': 1521261836,
#    'sunset': 1521305883},
#   'weather': [{'description': 'few clouds',
#     'icon': '02d',
#     'id': 801,
#     'main': 'Clouds'}],
#   'wind': {'deg': 79.5003, 'speed': 3.67}},
#  {'cod': '404', 'message': 'city not found'},
#  {'base': 'stations',
#   'clouds': {'all': 32},
#   'cod': 200,
#   'coord': {'lat': 72.79, 'lon': -56.15},
#   'dt': 1521276846,
#   'id': 3418910,
#   'main': {'grnd_level': 1032.47,
#    'humidity': 98,
#    'pressure': 1032.47,
#    'sea_level': 1036.02,
#    'temp': -22.5,
#    'temp_max': -22.5,
#    'temp_min': -22.5},
#   'name': 'Upernavik',
#   'sys': {'country': 'GL',
#    'message': 0.0139,
#    'sunrise': 1521280581,
#    'sunset': 1521323504},
#   'weather': [{'description': 'scattered clouds',
#     'icon': '03n',
#     'id': 802,
#     'main': 'Clouds'}],
#   'wind': {'deg': 357, 'speed': 8.02}},
#  {'base': 'stations',
#   'clouds': {'all': 80},
#   'cod': 200,
#   'coord': {'lat': -8.15, 'lon': 159.59},
#   'dt': 1521276847,
#   'id': 2109528,
#   'main': {'grnd_level': 1013.99,
#    'humidity': 100,
#    'pressure': 1013.99,
#    'sea_level': 1023.01,
#    'temp': 24.75,
#    'temp_max': 24.75,
#    'temp_min': 24.75},
#   'name': 'Buala',
#   'rain': {'3h': 5.49},
#   'sys': {'country': 'SB',
#    'message': 0.0032,
#    'sunrise': 1521228354,
#    'sunset': 1521272037},
#   'weather': [{'description': 'moderate rain',
#     'icon': '10n',
#     'id': 501,
#     'main': 'Rain'}],
#   'wind': {'deg': 358, 'speed': 2.12}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -46.43, 'lon': -67.52},
#   'dt': 1521276826,
#   'id': 3863379,
#   'main': {'grnd_level': 996.07,
#    'humidity': 92,
#    'pressure': 996.07,
#    'sea_level': 1017.5,
#    'temp': 7.75,
#    'temp_max': 7.75,
#    'temp_min': 7.75},
#   'name': 'Mar del Plata',
#   'sys': {'country': 'AR',
#    'message': 0.0071,
#    'sunrise': 1521282523,
#    'sunset': 1521326815},
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 261, 'speed': 3.62}},
#  {'base': 'stations',
#   'clouds': {'all': 88},
#   'cod': 200,
#   'coord': {'lat': 66.83, 'lon': 70.83},
#   'dt': 1521276848,
#   'id': 1486321,
#   'main': {'grnd_level': 1025.99,
#    'humidity': 83,
#    'pressure': 1025.99,
#    'sea_level': 1027.26,
#    'temp': -20.6,
#    'temp_max': -20.6,
#    'temp_min': -20.6},
#   'name': 'Yar-Sale',
#   'sys': {'country': 'RU',
#    'message': 0.0035,
#    'sunrise': 1521250113,
#    'sunset': 1521292992},
#   'weather': [{'description': 'overcast clouds',
#     'icon': '04d',
#     'id': 804,
#     'main': 'Clouds'}],
#   'wind': {'deg': 97.0003, 'speed': 7.72}},
#  {'base': 'stations',
#   'clouds': {'all': 68},
#   'cod': 200,
#   'coord': {'lat': -3.84, 'lon': -62.06},
#   'dt': 1521276849,
#   'id': 3664525,
#   'main': {'grnd_level': 1019.5,
#    'humidity': 95,
#    'pressure': 1019.5,
#    'sea_level': 1023.33,
#    'temp': 24,
#    'temp_max': 24,
#    'temp_min': 24},
#   'name': 'Codajas',
#   'sys': {'country': 'BR',
#    'message': 0.0032,
#    'sunrise': 1521281570,
#    'sunset': 1521325196},
#   'weather': [{'description': 'broken clouds',
#     'icon': '04n',
#     'id': 803,
#     'main': 'Clouds'}],
#   'wind': {'deg': 106, 'speed': 1.47}},
#  {'base': 'stations',
#   'clouds': {'all': 56},
#   'cod': 200,
#   'coord': {'lat': -0.86, 'lon': 131.25},
#   'dt': 1521276849,
#   'id': 1626542,
#   'main': {'grnd_level': 1019.02,
#    'humidity': 100,
#    'pressure': 1019.02,
#    'sea_level': 1021.83,
#    'temp': 27.85,
#    'temp_max': 27.85,
#    'temp_min': 27.85},
#   'name': 'Sorong',
#   'sys': {'country': 'ID',
#    'message': 0.0047,
#    'sunrise': 1521235199,
#    'sunset': 1521278799},
#   'weather': [{'description': 'broken clouds',
#     'icon': '04d',
#     'id': 803,
#     'main': 'Clouds'}],
#   'wind': {'deg': 16.5003, 'speed': 1.97}},
#  {'base': 'stations',
#   'clouds': {'all': 20},
#   'cod': 200,
#   'coord': {'lat': 32.76, 'lon': 34.97},
#   'dt': 1521273000,
#   'id': 293308,
#   'main': {'humidity': 55,
#    'pressure': 1018,
#    'temp': 17.22,
#    'temp_max': 19,
#    'temp_min': 16},
#   'name': 'Tirat Karmel',
#   'sys': {'country': 'IL',
#    'id': 5916,
#    'message': 0.0043,
#    'sunrise': 1521258461,
#    'sunset': 1521301774,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'few clouds',
#     'icon': '02d',
#     'id': 801,
#     'main': 'Clouds'}],
#   'wind': {'deg': 340, 'speed': 3.1}},
#  {'base': 'stations',
#   'clouds': {'all': 80},
#   'cod': 200,
#   'coord': {'lat': 15.34, 'lon': 74.49},
#   'dt': 1521276831,
#   'id': 1273574,
#   'main': {'grnd_level': 957.08,
#    'humidity': 77,
#    'pressure': 957.08,
#    'sea_level': 1021.35,
#    'temp': 28.3,
#    'temp_max': 28.3,
#    'temp_min': 28.3},
#   'name': 'Vaini',
#   'rain': {'3h': 2.314},
#   'sys': {'country': 'IN',
#    'message': 0.0043,
#    'sunrise': 1521248901,
#    'sunset': 1521292350},
#   'weather': [{'description': 'light rain',
#     'icon': '10d',
#     'id': 500,
#     'main': 'Rain'}],
#   'wind': {'deg': 138.5, 'speed': 1.67}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 12.18, 'lon': 6.51},
#   'dt': 1521276583,
#   'id': 2339937,
#   'main': {'grnd_level': 968.11,
#    'humidity': 29,
#    'pressure': 968.11,
#    'sea_level': 1022.56,
#    'temp': 33,
#    'temp_max': 33,
#    'temp_min': 33},
#   'name': 'Auki',
#   'sys': {'country': 'NG',
#    'message': 0.0036,
#    'sunrise': 1521265194,
#    'sunset': 1521308679},
#   'weather': [{'description': 'clear sky',
#     'icon': '01d',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 209.5, 'speed': 3.02}},
#  {'base': 'stations',
#   'clouds': {'all': 32},
#   'cod': 200,
#   'coord': {'lat': 72.79, 'lon': -56.15},
#   'dt': 1521276846,
#   'id': 3418910,
#   'main': {'grnd_level': 1032.47,
#    'humidity': 98,
#    'pressure': 1032.47,
#    'sea_level': 1036.02,
#    'temp': -22.5,
#    'temp_max': -22.5,
#    'temp_min': -22.5},
#   'name': 'Upernavik',
#   'sys': {'country': 'GL',
#    'message': 0.0139,
#    'sunrise': 1521280581,
#    'sunset': 1521323504},
#   'weather': [{'description': 'scattered clouds',
#     'icon': '03n',
#     'id': 802,
#     'main': 'Clouds'}],
#   'wind': {'deg': 357, 'speed': 8.02}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -43.03, 'lon': 147.26},
#   'dt': 1521273600,
#   'id': 2158744,
#   'main': {'humidity': 41,
#    'pressure': 1002,
#    'temp': 26,
#    'temp_max': 26,
#    'temp_min': 26},
#   'name': 'Margate',
#   'sys': {'country': 'AU',
#    'id': 8195,
#    'message': 0.0038,
#    'sunrise': 1521230982,
#    'sunset': 1521275288,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#     'icon': '01d',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 10, 'speed': 6.7}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 20.52, 'lon': -13.05},
#   'dt': 1521276852,
#   'id': 2381334,
#   'main': {'grnd_level': 998.67,
#    'humidity': 36,
#    'pressure': 998.67,
#    'sea_level': 1029.25,
#    'temp': 18.35,
#    'temp_max': 18.35,
#    'temp_min': 18.35},
#   'name': 'Atar',
#   'sys': {'country': 'MR',
#    'message': 0.004,
#    'sunrise': 1521269922,
#    'sunset': 1521313344},
#   'weather': [{'description': 'clear sky',
#     'icon': '01d',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 51.0003, 'speed': 6.62}},
#  {'base': 'stations',
#   'clouds': {'all': 64},
#   'cod': 200,
#   'coord': {'lat': -23.12, 'lon': -134.97},
#   'dt': 1521276824,
#   'id': 4030556,
#   'main': {'grnd_level': 1032.23,
#    'humidity': 96,
#    'pressure': 1032.23,
#    'sea_level': 1032.29,
#    'temp': 27.6,
#    'temp_max': 27.6,
#    'temp_min': 27.6},
#   'name': 'Rikitea',
#   'sys': {'country': 'PF',
#    'message': 0.0037,
#    'sunrise': 1521298958,
#    'sunset': 1521342780},
#   'weather': [{'description': 'broken clouds',
#     'icon': '04n',
#     'id': 803,
#     'main': 'Clouds'}],
#   'wind': {'deg': 90.0003, 'speed': 6.77}},
#  {'base': 'stations',
#   'clouds': {'all': 68},
#   'cod': 200,
#   'coord': {'lat': 61.56, 'lon': 45.93},
#   'dt': 1521276853,
#   'id': 542423,
#   'main': {'grnd_level': 1009.53,
#    'humidity': 51,
#    'pressure': 1009.53,
#    'sea_level': 1023.01,
#    'temp': -17.25,
#    'temp_max': -17.25,
#    'temp_min': -17.25},
#   'name': 'Krasnoborsk',
#   'sys': {'country': 'RU',
#    'message': 0.0036,
#    'sunrise': 1521256013,
#    'sunset': 1521299018},
#   'weather': [{'description': 'broken clouds',
#     'icon': '04d',
#     'id': 803,
#     'main': 'Clouds'}],
#   'wind': {'deg': 313, 'speed': 2.87}},
#  {'base': 'stations',
#   'clouds': {'all': 24},
#   'cod': 200,
#   'coord': {'lat': -19.06, 'lon': -169.92},
#   'dt': 1521273600,
#   'id': 4036284,
#   'main': {'humidity': 94,
#    'pressure': 1010,
#    'temp': 23,
#    'temp_max': 23,
#    'temp_min': 23},
#   'name': 'Alofi',
#   'sys': {'country': 'NU',
#    'id': 8341,
#    'message': 0.0036,
#    'sunrise': 1521307374,
#    'sunset': 1521351141,
#    'type': 1},
#   'weather': [{'description': 'few clouds',
#     'icon': '02n',
#     'id': 801,
#     'main': 'Clouds'}],
#   'wind': {'deg': 280, 'speed': 0.5}},
#  {'base': 'stations',
#   'clouds': {'all': 48},
#   'cod': 200,
#   'coord': {'lat': -8.93, 'lon': 125.41},
#   'dt': 1521276854,
#   'id': 1651810,
#   'main': {'grnd_level': 944.92,
#    'humidity': 56,
#    'pressure': 944.92,
#    'sea_level': 1021.31,
#    'temp': 26.85,
#    'temp_max': 26.85,
#    'temp_min': 26.85},
#   'name': 'Airai',
#   'rain': {'3h': 0.115},
#   'sys': {'country': 'TL',
#    'message': 0.0037,
#    'sunrise': 1521236552,
#    'sunset': 1521280242},
#   'weather': [{'description': 'light rain',
#     'icon': '10d',
#     'id': 500,
#     'main': 'Rain'}],
#   'wind': {'deg': 210.5, 'speed': 0.72}},
#  {'base': 'stations',
#   'clouds': {'all': 64},
#   'cod': 200,
#   'coord': {'lat': -23.12, 'lon': -134.97},
#   'dt': 1521276824,
#   'id': 4030556,
#   'main': {'grnd_level': 1032.23,
#    'humidity': 96,
#    'pressure': 1032.23,
#    'sea_level': 1032.29,
#    'temp': 27.6,
#    'temp_max': 27.6,
#    'temp_min': 27.6},
#   'name': 'Rikitea',
#   'sys': {'country': 'PF',
#    'message': 0.0037,
#    'sunrise': 1521298958,
#    'sunset': 1521342780},
#   'weather': [{'description': 'broken clouds',
#     'icon': '04n',
#     'id': 803,
#     'main': 'Clouds'}],
#   'wind': {'deg': 90.0003, 'speed': 6.77}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': -54.81, 'lon': -68.31},
#   'dt': 1521273600,
#   'id': 3833367,
#   'main': {'humidity': 100,
#    'pressure': 990,
#    'temp': 2,
#    'temp_max': 2,
#    'temp_min': 2},
#   'name': 'Ushuaia',
#   'sys': {'country': 'AR',
#    'id': 4754,
#    'message': 0.0038,
#    'sunrise': 1521282555,
#    'sunset': 1521327143,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#     'icon': '04n',
#     'id': 803,
#     'main': 'Clouds'}],
#   'wind': {'deg': 90, 'speed': 2.6}},
#  {'base': 'stations',
#   'clouds': {'all': 80},
#   'cod': 200,
#   'coord': {'lat': 15.34, 'lon': 74.49},
#   'dt': 1521276831,
#   'id': 1273574,
#   'main': {'grnd_level': 957.08,
#    'humidity': 77,
#    'pressure': 957.08,
#    'sea_level': 1021.35,
#    'temp': 28.3,
#    'temp_max': 28.3,
#    'temp_min': 28.3},
#   'name': 'Vaini',
#   'rain': {'3h': 2.314},
#   'sys': {'country': 'IN',
#    'message': 0.0043,
#    'sunrise': 1521248901,
#    'sunset': 1521292350},
#   'weather': [{'description': 'light rain',
#     'icon': '10d',
#     'id': 500,
#     'main': 'Rain'}],
#   'wind': {'deg': 138.5, 'speed': 1.67}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 11.28, 'lon': -15.83},
#   'dt': 1521273600,
#   'id': 2374583,
#   'main': {'humidity': 94,
#    'pressure': 1011,
#    'temp': 21,
#    'temp_max': 21,
#    'temp_min': 21},
#   'name': 'Bubaque',
#   'sys': {'country': 'GW',
#    'id': 6118,
#    'message': 0.0036,
#    'sunrise': 1521270549,
#    'sunset': 1521314044,
#    'type': 1},
#   'visibility': 8000,
#   'weather': [{'description': 'clear sky',
#     'icon': '01d',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 330, 'speed': 1.5}},
#  {'base': 'stations',
#   'clouds': {'all': 8},
#   'cod': 200,
#   'coord': {'lat': -46.19, 'lon': 168.86},
#   'dt': 1521276817,
#   'id': 6201424,
#   'main': {'grnd_level': 1021.93,
#    'humidity': 79,
#    'pressure': 1021.93,
#    'sea_level': 1037.36,
#    'temp': 7.65,
#    'temp_max': 7.65,
#    'temp_min': 7.65},
#   'name': 'Mataura',
#   'sys': {'country': 'NZ',
#    'message': 0.0042,
#    'sunrise': 1521225741,
#    'sunset': 1521270157},
#   'weather': [{'description': 'clear sky',
#     'icon': '02n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 128, 'speed': 2.12}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -23.7, 'lon': 133.88},
#   'dt': 1521273600,
#   'id': 2077895,
#   'main': {'humidity': 10,
#    'pressure': 1011,
#    'temp': 37,
#    'temp_max': 37,
#    'temp_min': 37},
#   'name': 'Alice Springs',
#   'sys': {'country': 'AU',
#    'id': 8163,
#    'message': 0.0032,
#    'sunrise': 1521234412,
#    'sunset': 1521278304,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#     'icon': '01d',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 160, 'speed': 2.6}},
#  {'base': 'stations',
#   'clouds': {'all': 5},
#   'cod': 200,
#   'coord': {'lat': 49.72, 'lon': -86.95},
#   'dt': 1521273600,
#   'id': 5960603,
#   'main': {'humidity': 60,
#    'pressure': 1015,
#    'temp': -14,
#    'temp_max': -14,
#    'temp_min': -14},
#   'name': 'Geraldton',
#   'sys': {'country': 'CA',
#    'id': 3656,
#    'message': 0.0037,
#    'sunrise': 1521287766,
#    'sunset': 1521331003,
#    'type': 1},
#   'visibility': 24140,
#   'weather': [{'description': 'clear sky',
#     'icon': '02n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 50, 'speed': 1.5}},
#  {'base': 'stations',
#   'clouds': {'all': 20},
#   'cod': 200,
#   'coord': {'lat': 19.71, 'lon': -155.08},
#   'dt': 1521273360,
#   'id': 5855927,
#   'main': {'humidity': 88,
#    'pressure': 1017,
#    'temp': 17.38,
#    'temp_max': 23,
#    'temp_min': 13},
#   'name': 'Hilo',
#   'sys': {'country': 'US',
#    'id': 818,
#    'message': 0.0044,
#    'sunrise': 1521303986,
#    'sunset': 1521347441,
#    'type': 1},
#   'visibility': 16093,
#   'weather': [{'description': 'few clouds',
#     'icon': '02n',
#     'id': 801,
#     'main': 'Clouds'}],
#   'wind': {'deg': 210, 'speed': 2.1}},
#  {'base': 'stations',
#   'clouds': {'all': 8},
#   'cod': 200,
#   'coord': {'lat': -46.19, 'lon': 168.86},
#   'dt': 1521276817,
#   'id': 6201424,
#   'main': {'grnd_level': 1021.93,
#    'humidity': 79,
#    'pressure': 1021.93,
#    'sea_level': 1037.36,
#    'temp': 7.65,
#    'temp_max': 7.65,
#    'temp_min': 7.65},
#   'name': 'Mataura',
#   'sys': {'country': 'NZ',
#    'message': 0.0042,
#    'sunrise': 1521225741,
#    'sunset': 1521270157},
#   'weather': [{'description': 'clear sky',
#     'icon': '02n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 128, 'speed': 2.12}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -35.55, 'lon': 138.62},
#   'dt': 1521273600,
#   'id': 2059470,
#   'main': {'humidity': 78,
#    'pressure': 1005,
#    'temp': 22,
#    'temp_max': 22,
#    'temp_min': 22},
#   'name': 'Victor Harbor',
#   'sys': {'country': 'AU',
#    'id': 8204,
#    'message': 0.0138,
#    'sunrise': 1521233156,
#    'sunset': 1521277271,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#     'icon': '01d',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 200, 'speed': 4.6}},
#  {'base': 'stations',
#   'clouds': {'all': 32},
#   'cod': 200,
#   'coord': {'lat': 72.79, 'lon': -56.15},
#   'dt': 1521276846,
#   'id': 3418910,
#   'main': {'grnd_level': 1032.47,
#    'humidity': 98,
#    'pressure': 1032.47,
#    'sea_level': 1036.02,
#    'temp': -22.5,
#    'temp_max': -22.5,
#    'temp_min': -22.5},
#   'name': 'Upernavik',
#   'sys': {'country': 'GL',
#    'message': 0.0139,
#    'sunrise': 1521280581,
#    'sunset': 1521323504},
#   'weather': [{'description': 'scattered clouds',
#     'icon': '03n',
#     'id': 802,
#     'main': 'Clouds'}],
#   'wind': {'deg': 357, 'speed': 8.02}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -34.58, 'lon': 150.85},
#   'dt': 1521273600,
#   'id': 6255012,
#   'main': {'humidity': 53,
#    'pressure': 1013,
#    'temp': 25,
#    'temp_max': 25,
#    'temp_min': 25},
#   'name': 'Flinders',
#   'sys': {'country': 'AU',
#    'id': 8231,
#    'message': 0.0042,
#    'sunrise': 1521230231,
#    'sunset': 1521274329,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#     'icon': '01d',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 90, 'speed': 3.6}},
#  {'base': 'stations',
#   'clouds': {'all': 40},
#   'cod': 200,
#   'coord': {'lat': 32.3, 'lon': -64.78},
#   'dt': 1521273300,
#   'id': 3573197,
#   'main': {'humidity': 55,
#    'pressure': 1013,
#    'temp': 16,
#    'temp_max': 16,
#    'temp_min': 16},
#   'name': 'Hamilton',
#   'sys': {'country': 'BM',
#    'id': 4169,
#    'message': 0.0036,
#    'sunrise': 1521282377,
#    'sunset': 1521325727,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'scattered clouds',
#     'icon': '03n',
#     'id': 802,
#     'main': 'Clouds'}],
#   'wind': {'deg': 300, 'gust': 20.6, 'speed': 13.9}},
#  {'base': 'stations',
#   'clouds': {'all': 56},
#   'cod': 200,
#   'coord': {'lat': -22.97, 'lon': -42.02},
#   'dt': 1521276862,
#   'id': 3471451,
#   'main': {'grnd_level': 1024.61,
#    'humidity': 91,
#    'pressure': 1024.61,
#    'sea_level': 1025.6,
#    'temp': 26.1,
#    'temp_max': 26.1,
#    'temp_min': 26.1},
#   'name': 'Arraial do Cabo',
#   'rain': {'3h': 0.2275},
#   'sys': {'country': 'BR',
#    'message': 0.0038,
#    'sunrise': 1521276645,
#    'sunset': 1521320486},
#   'weather': [{'description': 'light rain',
#     'icon': '10d',
#     'id': 500,
#     'main': 'Rain'}],
#   'wind': {'deg': 162.5, 'speed': 3.77}},
#  {'base': 'stations',
#   'clouds': {'all': 8},
#   'cod': 200,
#   'coord': {'lat': -46.19, 'lon': 168.86},
#   'dt': 1521276817,
#   'id': 6201424,
#   'main': {'grnd_level': 1021.93,
#    'humidity': 79,
#    'pressure': 1021.93,
#    'sea_level': 1037.36,
#    'temp': 7.65,
#    'temp_max': 7.65,
#    'temp_min': 7.65},
#   'name': 'Mataura',
#   'sys': {'country': 'NZ',
#    'message': 0.0042,
#    'sunrise': 1521225741,
#    'sunset': 1521270157},
#   'weather': [{'description': 'clear sky',
#     'icon': '02n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 128, 'speed': 2.12}},
#  {'base': 'stations',
#   'clouds': {'all': 40},
#   'cod': 200,
#   'coord': {'lat': 62.45, 'lon': -114.38},
#   'dt': 1521273600,
#   'id': 6185377,
#   'main': {'humidity': 78,
#    'pressure': 1021,
#    'temp': -12,
#    'temp_max': -12,
#    'temp_min': -12},
#   'name': 'Yellowknife',
#   'sys': {'country': 'CA',
#    'id': 3558,
#    'message': 0.0045,
#    'sunrise': 1521294408,
#    'sunset': 1521337561,
#    'type': 1},
#   'visibility': 24140,
#   'weather': [{'description': 'scattered clouds',
#     'icon': '03n',
#     'id': 802,
#     'main': 'Clouds'}],
#   'wind': {'deg': 110, 'speed': 3.6}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 55.64, 'lon': 95.45},
#   'dt': 1521276863,
#   'id': 1505529,
#   'main': {'grnd_level': 997.37,
#    'humidity': 93,
#    'pressure': 997.37,
#    'sea_level': 1039.14,
#    'temp': -1.9,
#    'temp_max': -1.9,
#    'temp_min': -1.9},
#   'name': 'Irbeyskoye',
#   'sys': {'country': 'RU',
#    'message': 0.0042,
#    'sunrise': 1521244100,
#    'sunset': 1521287149},
#   'weather': [{'description': 'clear sky',
#     'icon': '01d',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 246, 'speed': 1.62}},
#  {'base': 'stations',
#   'clouds': {'all': 92},
#   'cod': 200,
#   'coord': {'lat': -10.62, 'lon': 150.67},
#   'dt': 1521276864,
#   'id': 2132606,
#   'main': {'grnd_level': 1019.91,
#    'humidity': 100,
#    'pressure': 1019.91,
#    'sea_level': 1022.93,
#    'temp': 25.7,
#    'temp_max': 25.7,
#    'temp_min': 25.7},
#   'name': 'Samarai',
#   'rain': {'3h': 5.3},
#   'sys': {'country': 'PG',
#    'message': 0.0049,
#    'sunrise': 1521230479,
#    'sunset': 1521274191},
#   'weather': [{'description': 'moderate rain',
#     'icon': '10n',
#     'id': 501,
#     'main': 'Rain'}],
#   'wind': {'deg': 251, 'speed': 2.42}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -42.78, 'lon': 147.06},
#   'dt': 1521273600,
#   'id': 2155415,
#   'main': {'humidity': 41,
#    'pressure': 1002,
#    'temp': 26,
#    'temp_max': 26,
#    'temp_min': 26},
#   'name': 'New Norfolk',
#   'sys': {'country': 'AU',
#    'id': 8195,
#    'message': 0.0036,
#    'sunrise': 1521231033,
#    'sunset': 1521275333,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#     'icon': '01d',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 10, 'speed': 6.7}},
#  {'base': 'stations',
#   'clouds': {'all': 88},
#   'cod': 200,
#   'coord': {'lat': 66, 'lon': 57.56},
#   'dt': 1521276865,
#   'id': 863061,
#   'main': {'grnd_level': 1009.04,
#    'humidity': 88,
#    'pressure': 1009.04,
#    'sea_level': 1019.08,
#    'temp': -16.75,
#    'temp_max': -16.75,
#    'temp_min': -16.75},
#   'name': 'Usinsk',
#   'sys': {'country': 'RU',
#    'message': 0.0038,
#    'sunrise': 1521253278,
#    'sunset': 1521296191},
#   'weather': [{'description': 'overcast clouds',
#     'icon': '04d',
#     'id': 804,
#     'main': 'Clouds'}],
#   'wind': {'deg': 39.0003, 'speed': 3.17}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': 24.8, 'lon': 125.28},
#   'dt': 1521273600,
#   'id': 1862505,
#   'main': {'humidity': 73,
#    'pressure': 1017,
#    'temp': 22,
#    'temp_max': 22,
#    'temp_min': 22},
#   'name': 'Hirara',
#   'sys': {'country': 'JP',
#    'id': 7630,
#    'message': 0.0041,
#    'sunrise': 1521236765,
#    'sunset': 1521280121,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#     'icon': '04d',
#     'id': 803,
#     'main': 'Clouds'}],
#   'wind': {'deg': 60, 'speed': 5.1}},
#  {'base': 'stations',
#   'clouds': {'all': 64},
#   'cod': 200,
#   'coord': {'lat': 5.88, 'lon': 7.92},
#   'dt': 1521276866,
#   'id': 2352250,
#   'main': {'grnd_level': 1009.69,
#    'humidity': 94,
#    'pressure': 1009.69,
#    'sea_level': 1024.83,
#    'temp': 26.8,
#    'temp_max': 26.8,
#    'temp_min': 26.8},
#   'name': 'Afikpo',
#   'sys': {'country': 'NG',
#    'message': 0.0038,
#    'sunrise': 1521264826,
#    'sunset': 1521308364},
#   'weather': [{'description': 'broken clouds',
#     'icon': '04d',
#     'id': 803,
#     'main': 'Clouds'}],
#   'wind': {'deg': 232, 'speed': 3.47}},
#  {'cod': '404', 'message': 'city not found'},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': 70.47, 'lon': -68.59},
#   'dt': 1521273600,
#   'id': 5924351,
#   'main': {'humidity': 68,
#    'pressure': 1028,
#    'temp': -29,
#    'temp_max': -29,
#    'temp_min': -29},
#   'name': 'Clyde River',
#   'sys': {'country': 'CA',
#    'id': 3585,
#    'message': 0.0043,
#    'sunrise': 1521283522,
#    'sunset': 1521326514,
#    'type': 1},
#   'visibility': 14484,
#   'weather': [{'description': 'light snow',
#     'icon': '13n',
#     'id': 600,
#     'main': 'Snow'}],
#   'wind': {'deg': 290, 'speed': 5.1}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': -53.16, 'lon': -70.91},
#   'dt': 1521273600,
#   'id': 3874787,
#   'main': {'humidity': 70,
#    'pressure': 997,
#    'temp': 6,
#    'temp_max': 6,
#    'temp_min': 6},
#   'name': 'Punta Arenas',
#   'sys': {'country': 'CL',
#    'id': 4642,
#    'message': 0.0044,
#    'sunrise': 1521283216,
#    'sunset': 1521327734,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#     'icon': '04n',
#     'id': 803,
#     'main': 'Clouds'}],
#   'wind': {'deg': 290, 'speed': 6.7}},
#  {'base': 'stations',
#   'clouds': {'all': 56},
#   'cod': 200,
#   'coord': {'lat': -11.75, 'lon': -44.91},
#   'dt': 1521276869,
#   'id': 3451478,
#   'main': {'grnd_level': 956.68,
#    'humidity': 91,
#    'pressure': 956.68,
#    'sea_level': 1023.58,
#    'temp': 19.15,
#    'temp_max': 19.15,
#    'temp_min': 19.15},
#   'name': 'Riachao das Neves',
#   'sys': {'country': 'BR',
#    'message': 0.0039,
#    'sunrise': 1521277412,
#    'sunset': 1521321117},
#   'weather': [{'description': 'broken clouds',
#     'icon': '04n',
#     'id': 803,
#     'main': 'Clouds'}],
#   'wind': {'deg': 207.5, 'speed': 1.42}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 68.75, 'lon': 161.3},
#   'dt': 1521276870,
#   'id': 2126199,
#   'main': {'grnd_level': 1026.64,
#    'humidity': 0,
#    'pressure': 1026.64,
#    'sea_level': 1036.14,
#    'temp': -33.3,
#    'temp_max': -33.3,
# ...
#  {'base': 'stations',
#   'clouds': {'all': 8},
#   'cod': 200,
#   'coord': {'lat': -46.19, 'lon': 168.86},
#   'dt': 1521276817,
#   'id': 6201424,
#   'main': {'grnd_level': 1021.93,
#    'humidity': 79,
#    'pressure': 1021.93,
#    'sea_level': 1037.36,
#    'temp': 7.65,
#    'temp_max': 7.65,
#    'temp_min': 7.65},
#   'name': 'Mataura',
#   'sys': {'country': 'NZ',
#    'message': 0.0042,
#    'sunrise': 1521225741,
#    'sunset': 1521270157},
#   'weather': [{'description': 'clear sky',
#     'icon': '02n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 128, 'speed': 2.12}},
#  {'base': 'stations',
#   'clouds': {'all': 24},
#   'cod': 200,
#   'coord': {'lat': 71.98, 'lon': 102.47},
#   'dt': 1521277118,
#   'id': 2022572,
#   'main': {'grnd_level': 1040.82,
#    'humidity': 40,
#    'pressure': 1040.82,
#    'sea_level': 1046.19,
#    'temp': -32.2,
#    'temp_max': -32.2,
#    'temp_min': -32.2},
#   'name': 'Khatanga',
#   'sys': {'country': 'RU',
#    'message': 0.003,
#    'sunrise': 1521242634,
#    'sunset': 1521285321},
#   'weather': [{'description': 'few clouds',
#     'icon': '02d',
#     'id': 801,
#     'main': 'Clouds'}],
#   'wind': {'deg': 217.5, 'speed': 2.67}},
#  {'base': 'stations',
#   'clouds': {'all': 64},
#   'cod': 200,
#   'coord': {'lat': 50.68, 'lon': 156.12},
#   'dt': 1521277119,
#   'id': 2121385,
#   'main': {'grnd_level': 1003.86,
#    'humidity': 100,
#    'pressure': 1003.86,
#    'sea_level': 1017.7,
#    'temp': -6.2,
#    'temp_max': -6.2,
#    'temp_min': -6.2},
#   'name': 'Severo-Kurilsk',
#   'sys': {'country': 'RU',
#    'message': 0.0035,
#    'sunrise': 1521229524,
#    'sunset': 1521272598},
#   'weather': [{'description': 'broken clouds',
#     'icon': '04n',
#     'id': 803,
#     'main': 'Clouds'}],
#   'wind': {'deg': 272, 'speed': 11.32}},
#  {'base': 'stations',
#   'clouds': {'all': 64},
#   'cod': 200,
#   'coord': {'lat': -23.12, 'lon': -134.97},
#   'dt': 1521276824,
#   'id': 4030556,
#   'main': {'grnd_level': 1032.23,
#    'humidity': 96,
#    'pressure': 1032.23,
#    'sea_level': 1032.29,
#    'temp': 27.6,
#    'temp_max': 27.6,
#    'temp_min': 27.6},
#   'name': 'Rikitea',
#   'sys': {'country': 'PF',
#    'message': 0.0037,
#    'sunrise': 1521298958,
#    'sunset': 1521342780},
#   'weather': [{'description': 'broken clouds',
#     'icon': '04n',
#     'id': 803,
#     'main': 'Clouds'}],
#   'wind': {'deg': 90.0003, 'speed': 6.77}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -46.28, 'lon': 169.85},
#   'dt': 1521277008,
#   'id': 2208248,
#   'main': {'grnd_level': 1021.04,
#    'humidity': 69,
#    'pressure': 1021.04,
#    'sea_level': 1038.29,
#    'temp': 11.05,
#    'temp_max': 11.05,
#    'temp_min': 11.05},
#   'name': 'Kaitangata',
#   'sys': {'country': 'NZ',
#    'message': 0.0041,
#    'sunrise': 1521225502,
#    'sunset': 1521269921},
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 54.0003, 'speed': 6.12}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 45.6, 'lon': -0.6},
#   'dt': 1521275400,
#   'id': 3026644,
#   'main': {'humidity': 87,
#    'pressure': 999,
#    'temp': 5.9,
#    'temp_max': 7,
#    'temp_min': 5},
#   'name': 'Souillac',
#   'sys': {'country': 'FR',
#    'id': 5528,
#    'message': 0.0063,
#    'sunrise': 1521267051,
#    'sunset': 1521310272,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#     'icon': '01d',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 130, 'speed': 1.5}},
#  {'base': 'stations',
#   'clouds': {'all': 56},
#   'cod': 200,
#   'coord': {'lat': 7.2, 'lon': 124.8},
#   'dt': 1521277121,
#   'id': 1718338,
#   'main': {'grnd_level': 1004.99,
#    'humidity': 85,
#    'pressure': 1004.99,
#    'sea_level': 1021.79,
#    'temp': 25.75,
#    'temp_max': 25.75,
#    'temp_min': 25.75},
#   'name': 'Carmen',
#   'rain': {'3h': 5.345},
#   'sys': {'country': 'PH',
#    'message': 0.0045,
#    'sunrise': 1521236791,
#    'sunset': 1521280310},
#   'weather': [{'description': 'moderate rain',
#     'icon': '10d',
#     'id': 501,
#     'main': 'Rain'}],
#   'wind': {'deg': 58.0003, 'speed': 1.87}},
#  {'base': 'stations',
#   'clouds': {'all': 88},
#   'cod': 200,
#   'coord': {'lat': 33.6, 'lon': 56.92},
#   'dt': 1521277121,
#   'id': 113659,
#   'main': {'grnd_level': 900.75,
#    'humidity': 25,
#    'pressure': 900.75,
#    'sea_level': 1016.04,
#    'temp': 23.2,
#    'temp_max': 23.2,
#    'temp_min': 23.2},
#   'name': 'Tabas',
#   'sys': {'country': 'IR',
#    'message': 0.0047,
#    'sunrise': 1521253201,
#    'sunset': 1521296500},
#   'weather': [{'description': 'overcast clouds',
#     'icon': '04d',
#     'id': 804,
#     'main': 'Clouds'}],
#   'wind': {'deg': 189, 'speed': 4.77}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -33.21, 'lon': 138.6},
#   'dt': 1521276792,
#   'id': 2069194,
#   'main': {'grnd_level': 963.57,
#    'humidity': 23,
#    'pressure': 963.57,
#    'sea_level': 1020.25,
#    'temp': 27.9,
#    'temp_max': 27.9,
#    'temp_min': 27.9},
#   'name': 'Jamestown',
#   'sys': {'country': 'AU',
#    'message': 0.0035,
#    'sunrise': 1521233187,
#    'sunset': 1521277252},
#   'weather': [{'description': 'clear sky',
#     'icon': '01d',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 308, 'speed': 3.82}},
#  {'base': 'stations',
#   'clouds': {'all': 92},
#   'cod': 200,
#   'coord': {'lat': 1.6, 'lon': 11.57},
#   'dt': 1521277122,
#   'id': 2396646,
#   'main': {'grnd_level': 968.76,
#    'humidity': 100,
#    'pressure': 968.76,
#    'sea_level': 1025.72,
#    'temp': 21.25,
#    'temp_max': 21.25,
#    'temp_min': 21.25},
#   'name': 'Oyem',
#   'rain': {'3h': 7.0225},
#   'sys': {'country': 'GA',
#    'message': 0.0036,
#    'sunrise': 1521263929,
#    'sunset': 1521307506},
#   'weather': [{'description': 'moderate rain',
#     'icon': '10d',
#     'id': 501,
#     'main': 'Rain'}],
#   'wind': {'deg': 58.5003, 'speed': 0.47}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -33.64, 'lon': 115.35},
#   'dt': 1521276834,
#   'id': 2075265,
#   'main': {'grnd_level': 1032.23,
#    'humidity': 100,
#    'pressure': 1032.23,
#    'sea_level': 1033.3,
#    'temp': 19.35,
#    'temp_max': 19.35,
#    'temp_min': 19.35},
#   'name': 'Busselton',
#   'sys': {'country': 'AU',
#    'message': 0.0034,
#    'sunrise': 1521238766,
#    'sunset': 1521282831},
#   'weather': [{'description': 'clear sky',
#     'icon': '01d',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 187.5, 'speed': 8.72}},
#  {'base': 'stations',
#   'clouds': {'all': 48},
#   'cod': 200,
#   'coord': {'lat': -15.89, 'lon': -52.26},
#   'dt': 1521277124,
#   'id': 3470709,
#   'main': {'grnd_level': 976.94,
#    'humidity': 91,
#    'pressure': 976.94,
#    'sea_level': 1023.86,
#    'temp': 22.45,
#    'temp_max': 22.45,
#    'temp_min': 22.45},
#   'name': 'Barra do Garcas',
#   'sys': {'country': 'BR',
#    'message': 0.0037,
#    'sunrise': 1521279151,
#    'sunset': 1521322901},
#   'weather': [{'description': 'scattered clouds',
#     'icon': '03n',
#     'id': 802,
#     'main': 'Clouds'}],
#   'wind': {'deg': 222.5, 'speed': 1.02}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 77.48, 'lon': -69.36},
#   'dt': 1521276828,
#   'id': 3831208,
#   'main': {'grnd_level': 1004.5,
#    'humidity': 65,
#    'pressure': 1004.5,
#    'sea_level': 1040.35,
#    'temp': -30.35,
#    'temp_max': -30.35,
#    'temp_min': -30.35},
#   'name': 'Qaanaaq',
#   'sys': {'country': 'GL',
#    'message': 0.0038,
#    'sunrise': 1521283838,
#    'sunset': 1521326646},
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 94.5003, 'speed': 3.37}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': 45.36, 'lon': -73.48},
#   'dt': 1521274500,
#   'id': 6138908,
#   'main': {'humidity': 41,
#    'pressure': 1005,
#    'temp': -8.78,
#    'temp_max': -7,
#    'temp_min': -11},
#   'name': 'Saint-Philippe',
#   'sys': {'country': 'CA',
#    'id': 3851,
#    'message': 0.0103,
#    'sunrise': 1521284518,
#    'sunset': 1521327780,
#    'type': 1},
#   'visibility': 14484,
#   'weather': [{'description': 'broken clouds',
#     'icon': '04n',
#     'id': 803,
#     'main': 'Clouds'}],
#   'wind': {'deg': 280, 'speed': 4.6}},
#  {'base': 'stations',
#   'clouds': {'all': 90},
#   'cod': 200,
#   'coord': {'lat': 22.08, 'lon': -159.32},
#   'dt': 1521275940,
#   'id': 5848280,
#   'main': {'humidity': 94,
#    'pressure': 1018,
#    'temp': 22.37,
#    'temp_max': 23,
#    'temp_min': 22},
#   'name': 'Kapaa',
#   'sys': {'country': 'US',
#    'id': 833,
#    'message': 0.0053,
#    'sunrise': 1521305011,
#    'sunset': 1521348452,
#    'type': 1},
#   'visibility': 16093,
#   'weather': [{'description': 'overcast clouds',
#     'icon': '04n',
#     'id': 804,
#     'main': 'Clouds'}],
#   'wind': {'deg': 25.0003, 'speed': 1.87}},
#  {'base': 'stations',
#   'clouds': {'all': 64},
#   'cod': 200,
#   'coord': {'lat': -23.12, 'lon': -134.97},
#   'dt': 1521276824,
#   'id': 4030556,
#   'main': {'grnd_level': 1032.23,
#    'humidity': 96,
#    'pressure': 1032.23,
#    'sea_level': 1032.29,
#    'temp': 27.6,
#    'temp_max': 27.6,
#    'temp_min': 27.6},
#   'name': 'Rikitea',
#   'sys': {'country': 'PF',
#    'message': 0.0037,
#    'sunrise': 1521298958,
#    'sunset': 1521342780},
#   'weather': [{'description': 'broken clouds',
#     'icon': '04n',
#     'id': 803,
#     'main': 'Clouds'}],
#   'wind': {'deg': 90.0003, 'speed': 6.77}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 77.48, 'lon': -69.36},
#   'dt': 1521276828,
#   'id': 3831208,
#   'main': {'grnd_level': 1004.5,
#    'humidity': 65,
#    'pressure': 1004.5,
#    'sea_level': 1040.35,
#    'temp': -30.35,
#    'temp_max': -30.35,
#    'temp_min': -30.35},
#   'name': 'Qaanaaq',
#   'sys': {'country': 'GL',
#    'message': 0.0038,
#    'sunrise': 1521283838,
#    'sunset': 1521326646},
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 94.5003, 'speed': 3.37}},
#  {'base': 'stations',
#   'clouds': {'all': 80},
#   'cod': 200,
#   'coord': {'lat': 15.34, 'lon': 74.49},
#   'dt': 1521276831,
#   'id': 1273574,
#   'main': {'grnd_level': 957.08,
#    'humidity': 77,
#    'pressure': 957.08,
#    'sea_level': 1021.35,
#    'temp': 28.3,
#    'temp_max': 28.3,
#    'temp_min': 28.3},
#   'name': 'Vaini',
#   'rain': {'3h': 2.314},
#   'sys': {'country': 'IN',
#    'message': 0.0043,
#    'sunrise': 1521248901,
#    'sunset': 1521292350},
#   'weather': [{'description': 'light rain',
#     'icon': '10d',
#     'id': 500,
#     'main': 'Rain'}],
#   'wind': {'deg': 138.5, 'speed': 1.67}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -33.93, 'lon': 18.42},
#   'dt': 1521276120,
#   'id': 3369157,
#   'main': {'humidity': 38,
#    'pressure': 1018,
#    'temp': 24,
#    'temp_max': 24,
#    'temp_min': 24},
#   'name': 'Cape Town',
#   'sys': {'country': 'ZA',
#    'id': 6529,
#    'message': 0.0047,
#    'sunrise': 1521262038,
#    'sunset': 1521306075,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#     'icon': '01d',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 220, 'speed': 2.6}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': 55.74, 'lon': -97.86},
#   'dt': 1521273600,
#   'id': 6165406,
#   'main': {'humidity': 61,
#    'pressure': 1011,
#    'temp': -10,
#    'temp_max': -10,
#    'temp_min': -10},
#   'name': 'Thompson',
#   'sys': {'country': 'CA',
#    'id': 3406,
#    'message': 0.0027,
#    'sunrise': 1521290411,
#    'sunset': 1521333608,
#    'type': 1},
#   'visibility': 24140,
#   'weather': [{'description': 'broken clouds',
#     'icon': '04n',
#     'id': 803,
#     'main': 'Clouds'}],
#   'wind': {'deg': 70, 'speed': 1.5}},
#  {'base': 'stations',
#   'clouds': {'all': 32},
#   'cod': 200,
#   'coord': {'lat': 71.97, 'lon': 114.09},
#   'dt': 1521277024,
#   'id': 2017155,
#   'main': {'grnd_level': 1027.53,
#    'humidity': 56,
#    'pressure': 1027.53,
#    'sea_level': 1040.96,
#    'temp': -28.4,
#    'temp_max': -28.4,
#    'temp_min': -28.4},
#   'name': 'Saskylakh',
#   'sys': {'country': 'RU',
#    'message': 0.0032,
#    'sunrise': 1521239855,
#    'sunset': 1521282523},
#   'weather': [{'description': 'scattered clouds',
#     'icon': '03d',
#     'id': 802,
#     'main': 'Clouds'}],
#   'wind': {'deg': 289.5, 'speed': 3.97}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -42.78, 'lon': 147.06},
#   'dt': 1521273600,
#   'id': 2155415,
#   'main': {'humidity': 41,
#    'pressure': 1002,
#    'temp': 26,
#    'temp_max': 26,
#    'temp_min': 26},
#   'name': 'New Norfolk',
#   'sys': {'country': 'AU',
#    'id': 8195,
#    'message': 0.0036,
#    'sunrise': 1521231033,
#    'sunset': 1521275333,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#     'icon': '01d',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 10, 'speed': 6.7}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': 37.14, 'lon': -8.45},
#   'dt': 1521275400,
#   'id': 2267254,
#   'main': {'humidity': 77,
#    'pressure': 1009,
#    'temp': 15,
#    'temp_max': 15,
#    'temp_min': 15},
#   'name': 'Lagoa',
#   'sys': {'country': 'PT',
#    'id': 5948,
#    'message': 0.0041,
#    'sunrise': 1521268892,
#    'sunset': 1521312186,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#     'icon': '04d',
#     'id': 803,
#     'main': 'Clouds'}],
#   'wind': {'deg': 240, 'speed': 10.8}},
#  {'base': 'stations',
#   'clouds': {'all': 32},
#   'cod': 200,
#   'coord': {'lat': -0.74, 'lon': -90.35},
#   'dt': 1521276911,
#   'id': 3652764,
#   'main': {'grnd_level': 1016.34,
#    'humidity': 100,
#    'pressure': 1016.34,
#    'sea_level': 1023.41,
#    'temp': 25.15,
#    'temp_max': 25.15,
#    'temp_min': 25.15},
#   'name': 'Puerto Ayora',
#   'sys': {'country': 'EC',
#    'message': 0.0039,
#    'sunrise': 1521288374,
#    'sunset': 1521331971},
#   'weather': [{'description': 'scattered clouds',
#     'icon': '03n',
#     'id': 802,
#     'main': 'Clouds'}],
#   'wind': {'deg': 137.5, 'speed': 1.17}},
#  {'base': 'stations',
#   'clouds': {'all': 12},
#   'cod': 200,
#   'coord': {'lat': 71.64, 'lon': 128.87},
#   'dt': 1521276980,
#   'id': 2015306,
#   'main': {'grnd_level': 1016.5,
#    'humidity': 38,
#    'pressure': 1016.5,
#    'sea_level': 1036.3,
#    'temp': -31.85,
#    'temp_max': -31.85,
#    'temp_min': -31.85},
#   'name': 'Tiksi',
#   'sys': {'country': 'RU',
#    'message': 0.0042,
#    'sunrise': 1521236313,
#    'sunset': 1521278969},
#   'weather': [{'description': 'few clouds',
#     'icon': '02d',
#     'id': 801,
#     'main': 'Clouds'}],
#   'wind': {'deg': 346.5, 'speed': 2.07}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -13.71, 'lon': -76.2},
#   'dt': 1521273600,
#   'id': 3932145,
#   'main': {'humidity': 73,
#    'pressure': 1011,
#    'temp': 22,
#    'temp_max': 22,
#    'temp_min': 22},
#   'name': 'Pisco',
#   'sys': {'country': 'PE',
#    'id': 4405,
#    'message': 0.0038,
#    'sunrise': 1521284910,
#    'sunset': 1521328633,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 210, 'speed': 3.1}},
#  {'base': 'stations',
#   'clouds': {'all': 48},
#   'cod': 200,
#   'coord': {'lat': -33.59, 'lon': 26.89},
#   'dt': 1521276829,
#   'id': 964432,
#   'main': {'grnd_level': 1029.07,
#    'humidity': 87,
#    'pressure': 1029.07,
#    'sea_level': 1037.96,
#    'temp': 20.65,
#    'temp_max': 20.65,
#    'temp_min': 20.65},
#   'name': 'Port Alfred',
#   'sys': {'country': 'ZA',
#    'message': 0.0038,
#    'sunrise': 1521260008,
#    'sunset': 1521304041},
#   'weather': [{'description': 'scattered clouds',
#     'icon': '03d',
#     'id': 802,
#     'main': 'Clouds'}],
#   'wind': {'deg': 79.5003, 'speed': 6.42}},
#  {'base': 'stations',
#   'clouds': {'all': 90},
#   'cod': 200,
#   'coord': {'lat': 22.08, 'lon': -159.32},
#   'dt': 1521275940,
#   'id': 5848280,
#   'main': {'humidity': 94,
#    'pressure': 1018,
#    'temp': 22.37,
#    'temp_max': 23,
#    'temp_min': 22},
#   'name': 'Kapaa',
#   'sys': {'country': 'US',
#    'id': 833,
#    'message': 0.0053,
#    'sunrise': 1521305011,
#    'sunset': 1521348452,
#    'type': 1},
#   'visibility': 16093,
#   'weather': [{'description': 'overcast clouds',
#     'icon': '04n',
#     'id': 804,
#     'main': 'Clouds'}],
#   'wind': {'deg': 25.0003, 'speed': 1.87}}]

# %% [markdown]
# ##### Performing API calls to retrieve variables of interest in json dump

# %%
units = "metric"
  
for index,row in coordinates_df.iterrows():
    nc = row['Nearest City']
    queryString = weather_url + "appid=" + weather_apiKey + "&q=" + nc + "&units=" + units
    try: 
        weather_response = req.get(queryString)
        weather_data = req.get(queryString).json()

        coordinates_df.set_value(index,'Maximum Temperature',weather_data['main']['temp_max'])
        coordinates_df.set_value(index,'Humidity',weather_data['main']['humidity'])
        coordinates_df.set_value(index,'Cloudiness',weather_data['clouds']['all'])
        coordinates_df.set_value(index,'Wind Speed',weather_data['wind']['speed'])
       
    except:
        print('City does not exist')

coordinates_df
coordinates_df.rename(columns={'Maximum Temperature': 'Max_Temp'}, inplace=True)
coordinates_df.dropna()
coordinates_df.head()
# Out:
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
# City does not exist
#     Latitude  Longtitude    Nearest City  Max_Temp  Humidity  Cloudiness  \
# 0  -8.921170 -126.889341          atuona     27.95      98.0        92.0
# 1 -77.357296 -146.751413         mataura      7.65      79.0         8.0
# 2 -52.958458  131.446244   mount gambier     28.15      27.0        92.0
# 3  18.990164 -127.549987  guerrero negro     13.80      85.0        92.0
# 4 -28.651762 -145.698630         mataura      7.65      79.0         8.0
#
#    Wind Speed
# 0        7.17
# 1        2.12
# 2        6.12
# 3        5.27
# 4        2.12

# %%
coordinates_df.to_csv('apihomeworkdata.csv')

# %% [markdown]
# --------------

# %% [markdown]
# # PLOTTING DATA

# %% [markdown]
# ---------

# %% [markdown]
# ## Latitude vs Maximum Temperature Plot

# %%
sns.lmplot('Latitude','Max_Temp',data=coordinates_df,fit_reg=False)
sns.set_style('darkgrid')
plt.title('City Latitude vs. Maximum Temperature')
plt.xlabel('Latitude')
plt.ylabel('Maximum Temperature (F)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-5c73d582954d> in <module>()
# ----> 1 sns.lmplot('Latitude','Max_Temp',data=coordinates_df,fit_reg=False)
#       2 sns.set_style('darkgrid')
#       3 plt.title('City Latitude vs. Maximum Temperature')
#       4 plt.xlabel('Latitude')
#       5 plt.ylabel('Maximum Temperature (F)')
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/regression.py in lmplot(x, y, data, hue, col, row, palette, col_wrap, size, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws)
#     577     if sharex:
#     578         for ax in facets.axes.flat:
# --> 579             ax.scatter(data[x], np.ones(len(data)) * data[y].mean()).remove()
#     580
#     581     # Draw the regression plot on each facet
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in wrapper(left, right, name, na_op)
#     719                 lvalues = lvalues.values
#     720
# --> 721         result = wrap_results(safe_na_op(lvalues, rvalues))
#     722         return construct_result(
#     723             left,
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in safe_na_op(lvalues, rvalues)
#     680         try:
#     681             with np.errstate(all='ignore'):
# --> 682                 return na_op(lvalues, rvalues)
#     683         except Exception:
#     684             if isinstance(rvalues, ABCSeries):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in na_op(x, y)
#     656         try:
#     657             result = expressions.evaluate(op, str_rep, x, y,
# --> 658                                           raise_on_error=True, **eval_kwargs)
#     659         except TypeError:
#     660             if isinstance(y, (np.ndarray, ABCSeries, pd.Index)):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/computation/expressions.py in evaluate(op, op_str, a, b, raise_on_error, use_numexpr, **eval_kwargs)
#     209     if use_numexpr:
#     210         return _evaluate(op, op_str, a, b, raise_on_error=raise_on_error,
# --> 211                          **eval_kwargs)
#     212     return _evaluate_standard(op, op_str, a, b, raise_on_error=raise_on_error)
#     213
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b, raise_on_error, truediv, reversed, **eval_kwargs)
#     120
#     121     if result is None:
# --> 122         result = _evaluate_standard(op, op_str, a, b, raise_on_error)
#     123
#     124     return result
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/computation/expressions.py in _evaluate_standard(op, op_str, a, b, raise_on_error, **eval_kwargs)
#      62         _store_test_result(False)
#      63     with np.errstate(all='ignore'):
# ---> 64         return op(a, b)
#      65
#      66
#
# ValueError: operands could not be broadcast together with shapes (2,) (600,)

# %% [markdown]
# ## Latitude vs Humidity Plot

# %%
sns.lmplot('Latitude','Humidity',data=coordinates_df,fit_reg=False)
sns.set_style('darkgrid')
plt.title('City Latitude vs. Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.savefig('Latitude_vs_Humidity.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-31a78025b70c> in <module>()
# ----> 1 sns.lmplot('Latitude','Humidity',data=coordinates_df,fit_reg=False)
#       2 sns.set_style('darkgrid')
#       3 plt.title('City Latitude vs. Humidity')
#       4 plt.xlabel('Latitude')
#       5 plt.ylabel('Humidity (%)')
#
# NameError: name 'sns' is not defined

# %% [markdown]
# ## Latitude vs Cloudiness Plot

# %%
sns.lmplot('Latitude','Cloudiness',data=coordinates_df,fit_reg=False)
sns.set_style('darkgrid')
plt.title('City Latitude vs. Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.show()

# %% [markdown]
# ## Latitude vs Wind Speed

# %%
sns.lmplot('Latitude','Wind Speed',data=coordinates_df,fit_reg=False)
sns.set_style('darkgrid')
plt.title('City Latitude vs. Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.show()
